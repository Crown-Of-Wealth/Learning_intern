# %%
data = pd.read_csv('Learning_Intern_Raw_Data.csv', sep=',')
data
# Out:
#                               user_id  gender age_range               phone  \
# 0      6531ed09-304e-9573-a9c2-54e917  FEMALE     25-29  ["23409089964086"]
# 1      6531ed09-304e-9573-a9c2-54e917  FEMALE     25-29  ["23409089964086"]
# 2      6531ed09-304e-9573-a9c2-54e917  FEMALE     25-29  ["23409089964086"]
# 3      6531ed09-304e-9573-a9c2-54e917  FEMALE     25-29  ["23409089964086"]
# 4      6531ed09-304e-9573-a9c2-54e917  FEMALE     25-29  ["23409089964086"]
# ...                               ...     ...       ...                 ...
# 65528  95539e11-a210-2b56-d5a4-a1b85f  FEMALE     30-34  ["23408067849026"]
# 65529  95539e11-a210-2b56-d5a4-a1b85f  FEMALE     30-34  ["23408067849026"]
# 65530  95539e11-a210-2b56-d5a4-a1b85f  FEMALE     30-34  ["23408067849026"]
# 65531  95539e11-a210-2b56-d5a4-a1b85f  FEMALE     30-34  ["23408067849026"]
# 65532  95539e11-a210-2b56-d5a4-a1b85f  FEMALE     30-34  ["23408067849026"]
#
#        state               program               assignment_name  \
# 0      Lagos       Cloud Computing                  Milestone #1
# 1      Lagos       Cloud Computing                Weekly Test #1
# 2      Lagos       Cloud Computing                  Milestone #2
# 3      Lagos       Cloud Computing                Weekly Test #2
# 4      Lagos       Cloud Computing                  Milestone #3
# ...      ...                   ...                           ...
# 65528  Lagos  AI Career Essentials                  Milestone #5
# 65529  Lagos  AI Career Essentials                Weekly Test #5
# 65530  Lagos  AI Career Essentials                  Milestone #6
# 65531  Lagos  AI Career Essentials                Weekly Test #6
# 65532  Lagos  AI Career Essentials  AiCE Final Grace Period Test
#
#       assignment_type  assignment_score has_logged_into_lms  \
# 0           milestone            100.00                 Yes
# 1                test             95.23                 Yes
# 2           milestone             94.55                 Yes
# 3                test             90.90                 Yes
# 4           milestone            100.00                 Yes
# ...               ...               ...                 ...
# 65528       milestone            100.00                 Yes
# 65529            test            100.00                 Yes
# 65530       milestone            100.00                 Yes
# 65531            test            100.00                 Yes
# 65532            test              0.00                 Yes
#
#       Is assignment resubmitted learner_deferred  learner_dropped_off  \
# 0                            No               No                  NaN
# 1                            No               No                  NaN
# 2                            No               No                  NaN
# 3                            No               No                  NaN
# 4                            No               No                  NaN
# ...                         ...              ...                  ...
# 65528                        No               No                  NaN
# 65529                       Yes               No                  NaN
# 65530                        No               No                  NaN
# 65531                       Yes               No                  NaN
# 65532                        No               No                  NaN
#
#        overall_score  graduated
# 0                NaN        NaN
# 1                NaN        NaN
# 2                NaN        NaN
# 3                NaN        NaN
# 4                NaN        NaN
# ...              ...        ...
# 65528            NaN        NaN
# 65529            NaN        NaN
# 65530            NaN        NaN
# 65531            NaN        NaN
# 65532            NaN        NaN
#
# [65533 rows x 15 columns]

# %%
import pandas as pd
import numpy as np

# %%
# Drop unnecessary columns
df = data[['user_id', 'program', 'assignment_name', 'assignment_type', 'assignment_score', 'has_logged_into_lms', 'Is assignment resubmitted', 'learner_deferred', 'learner_dropped_off', 'overall_score', 'graduated']]

# %%
# Filter only 'test' assignment types
test_scores = df[df['assignment_type'] == 'test']
test_scores
# Out:
#                               user_id               program  \
# 1      6531ed09-304e-9573-a9c2-54e917       Cloud Computing
# 3      6531ed09-304e-9573-a9c2-54e917       Cloud Computing
# 5      6531ed09-304e-9573-a9c2-54e917       Cloud Computing
# 7      6531ed09-304e-9573-a9c2-54e917       Cloud Computing
# 9      6531ed09-304e-9573-a9c2-54e917       Cloud Computing
# ...                               ...                   ...
# 65525  95539e11-a210-2b56-d5a4-a1b85f  AI Career Essentials
# 65527  95539e11-a210-2b56-d5a4-a1b85f  AI Career Essentials
# 65529  95539e11-a210-2b56-d5a4-a1b85f  AI Career Essentials
# 65531  95539e11-a210-2b56-d5a4-a1b85f  AI Career Essentials
# 65532  95539e11-a210-2b56-d5a4-a1b85f  AI Career Essentials
#
#                     assignment_name assignment_type  assignment_score  \
# 1                    Weekly Test #1            test             95.23
# 3                    Weekly Test #2            test             90.90
# 5                    Weekly Test #3            test            100.00
# 7                    Weekly Test #4            test              0.00
# 9                    Weekly Test #5            test              0.00
# ...                             ...             ...               ...
# 65525                Weekly Test #3            test            100.00
# 65527                Weekly Test #4            test             80.95
# 65529                Weekly Test #5            test            100.00
# 65531                Weekly Test #6            test            100.00
# 65532  AiCE Final Grace Period Test            test              0.00
#
#       has_logged_into_lms Is assignment resubmitted learner_deferred  \
# 1                     Yes                        No               No
# 3                     Yes                        No               No
# 5                     Yes                        No               No
# 7                     Yes                        No               No
# 9                     Yes                        No               No
# ...                   ...                       ...              ...
# 65525                 Yes                        No               No
# 65527                 Yes                       Yes               No
# 65529                 Yes                       Yes               No
# 65531                 Yes                       Yes               No
# 65532                 Yes                        No               No
#
#        learner_dropped_off  overall_score  graduated
# 1                      NaN            NaN        NaN
# 3                      NaN            NaN        NaN
# 5                      NaN            NaN        NaN
# 7                      NaN            NaN        NaN
# 9                      NaN            NaN        NaN
# ...                    ...            ...        ...
# 65525                  NaN            NaN        NaN
# 65527                  NaN            NaN        NaN
# 65529                  NaN            NaN        NaN
# 65531                  NaN            NaN        NaN
# 65532                  NaN            NaN        NaN
#
# [35287 rows x 11 columns]

# %%
# Compute average test score per user
overall_scores = test_scores.groupby('user_id')['assignment_score'].mean()

# Merge computed scores back into the original DataFrame
df.loc[:, 'overall_score'] = df['user_id'].map(overall_scores)

# Save the updated file
df.to_excel("Updated_Learning_Intern.xlsx", index=False)

print("Overall scores updated successfully!")
# Out:
# Overall scores updated successfully!

# %%
df.head(15)
# Out:
#                            user_id          program  \
# 0   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 1   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 2   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 3   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 4   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 5   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 6   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 7   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 8   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 9   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 10  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 11  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 12  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 13  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 14  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
#
#                  assignment_name assignment_type  assignment_score  \
# 0                   Milestone #1       milestone            100.00
# 1                 Weekly Test #1            test             95.23
# 2                   Milestone #2       milestone             94.55
# 3                 Weekly Test #2            test             90.90
# 4                   Milestone #3       milestone            100.00
# 5                 Weekly Test #3            test            100.00
# 6                   Milestone #4       milestone              0.00
# 7                 Weekly Test #4            test              0.00
# 8                   Milestone #5       milestone              0.00
# 9                 Weekly Test #5            test              0.00
# 10                  Milestone #6       milestone              0.00
# 11                Weekly Test #6            test              0.00
# 12  AiCE Final Grace Period Test            test              0.00
# 13                  Milestone #1       milestone              0.00
# 14                Weekly Test #1            test            100.00
#
#    has_logged_into_lms Is assignment resubmitted learner_deferred  \
# 0                  Yes                        No               No
# 1                  Yes                        No               No
# 2                  Yes                        No               No
# 3                  Yes                        No               No
# 4                  Yes                        No               No
# 5                  Yes                        No               No
# 6                  Yes                        No               No
# 7                  Yes                        No               No
# 8                  Yes                        No               No
# 9                  Yes                        No               No
# 10                 Yes                        No               No
# 11                 Yes                        No               No
# 12                 Yes                        No               No
# 13                 Yes                        No               No
# 14                 Yes                        No               No
#
#     learner_dropped_off  overall_score  graduated
# 0                   NaN      40.875714        NaN
# 1                   NaN      40.875714        NaN
# 2                   NaN      40.875714        NaN
# 3                   NaN      40.875714        NaN
# 4                   NaN      40.875714        NaN
# 5                   NaN      40.875714        NaN
# 6                   NaN      40.875714        NaN
# 7                   NaN      40.875714        NaN
# 8                   NaN      40.875714        NaN
# 9                   NaN      40.875714        NaN
# 10                  NaN      40.875714        NaN
# 11                  NaN      40.875714        NaN
# 12                  NaN      40.875714        NaN
# 13                  NaN      90.247143        NaN
# 14                  NaN      90.247143        NaN

# %%
# Define the required milestone names
required_milestones = {"Milestone #1", "Milestone #2", "Milestone #3"}

# Identify users who have submitted all three required milestones
milestone_count = df[df['assignment_name'].isin(required_milestones)].groupby('user_id')['assignment_name'].nunique()

# Get users who have submitted all three milestones
#submitted_all = milestone_count[milestone_count == 3].index

# Mark dropped users (1 = dropped, 0 = not dropped)
#df.loc[:, 'learner_dropped_off'] = df['user_id'].apply(lambda x: 0 if x in submitted_all else 1)

# Save the updated DataFrame
#df.to_csv("updated_data.csv", index=False)

#print("Learners who didn't submit all milestones have been marked successfully!")

# %%
milestone_count.head(30)
# Out:
# user_id
# 0034a903-0652-77b3-9c70-82b91a    3
# 005a2866-1063-8f09-bf83-1cb6f4    3
# 005b9685-1114-e183-1b69-45964c    3
# 005d3e80-f153-c133-8dea-4e5b66    3
# 005f8882-251f-a015-ff42-c8e80c    3
# 0065897d-5ddf-d164-00c2-550e2e    3
# 006dd72c-cca9-6d4b-c4e3-8a1fa1    3
# 0084d940-dfcd-9b12-caf1-f97717    3
# 00990837-aa40-e32e-1ae1-07e04c    3
# 00a5a86d-343d-3a27-e9ab-be6f4f    3
# 00b795d6-f7b8-7904-f685-bef7d7    3
# 00d56c28-1c61-e176-fbd4-6acbac    3
# 00f46499-ad02-18ae-e634-9b5613    3
# 00fd6e8f-8ace-3e32-1b47-d9d0ed    3
# 011efd57-be84-24e9-8cbf-407d30    3
# 012a5010-4041-71ac-c5f3-ec0ced    3
# 0130e46f-a312-f5f6-ed88-fdbe87    3
# 014c1879-2025-1109-297f-57e7d8    3
# 014c4964-f107-a2b8-4322-e97bec    3
# 015c13b4-2e75-b42f-e756-80426e    3
# 01695c10-c70c-9ad3-c211-573a88    3
# 016eb9da-f9d5-052d-2b7a-b0268d    3
# 018cd55c-7f76-3d8d-bb30-921bea    3
# 019fe0fc-c55c-1481-1170-ea7bb2    3
# 01a42f8b-e640-eb7e-49f3-470827    3
# 01ae2569-1790-51a1-4f47-0e7e2b    3
# 01bfc37e-a357-fc18-ffa0-bbec1a    3
# 01c11a68-ff1f-6660-60d7-4788b4    3
# 01c18717-c32e-4587-fb25-439a0b    3
# 01c6cef4-187b-9d11-efa8-d6fdbb    3
# Name: assignment_name, dtype: int64

# %%
df.head(30)
# Out:
#                            user_id          program  \
# 0   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 1   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 2   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 3   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 4   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 5   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 6   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 7   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 8   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 9   6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 10  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 11  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 12  6531ed09-304e-9573-a9c2-54e917  Cloud Computing
# 13  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 14  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 15  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 16  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 17  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 18  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 19  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 20  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 21  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 22  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 23  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 24  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 25  aa6483d4-3df2-4a28-6598-1fa473   Data Analytics
# 26  87aa7e85-13eb-6db7-ab7f-f340ce     Data Science
# 27  87aa7e85-13eb-6db7-ab7f-f340ce     Data Science
# 28  87aa7e85-13eb-6db7-ab7f-f340ce     Data Science
# 29  87aa7e85-13eb-6db7-ab7f-f340ce     Data Science
#
#                  assignment_name assignment_type  assignment_score  \
# 0                   Milestone #1       milestone            100.00
# 1                 Weekly Test #1            test             95.23
# 2                   Milestone #2       milestone             94.55
# 3                 Weekly Test #2            test             90.90
# 4                   Milestone #3       milestone            100.00
# 5                 Weekly Test #3            test            100.00
# 6                   Milestone #4       milestone              0.00
# 7                 Weekly Test #4            test              0.00
# 8                   Milestone #5       milestone              0.00
# 9                 Weekly Test #5            test              0.00
# 10                  Milestone #6       milestone              0.00
# 11                Weekly Test #6            test              0.00
# 12  AiCE Final Grace Period Test            test              0.00
# 13                  Milestone #1       milestone              0.00
# 14                Weekly Test #1            test            100.00
# 15                  Milestone #2       milestone             50.00
# 16                Weekly Test #2            test             86.36
# 17                  Milestone #3       milestone            100.00
# 18                Weekly Test #3            test             85.00
# 19                  Milestone #4       milestone             89.03
# 20                Weekly Test #4            test             88.09
# 21                  Milestone #5       milestone            100.00
# 22                Weekly Test #5            test             90.47
# 23                  Milestone #6       milestone              0.00
# 24                Weekly Test #6            test             81.81
# 25  AiCE Final Grace Period Test            test            100.00
# 26                  Milestone #1       milestone              0.00
# 27                Weekly Test #1            test              0.00
# 28                  Milestone #2       milestone              0.00
# 29                Weekly Test #2            test              0.00
#
#    has_logged_into_lms Is assignment resubmitted learner_deferred  \
# 0                  Yes                        No               No
# 1                  Yes                        No               No
# 2                  Yes                        No               No
# 3                  Yes                        No               No
# 4                  Yes                        No               No
# 5                  Yes                        No               No
# 6                  Yes                        No               No
# 7                  Yes                        No               No
# 8                  Yes                        No               No
# 9                  Yes                        No               No
# 10                 Yes                        No               No
# 11                 Yes                        No               No
# 12                 Yes                        No               No
# 13                 Yes                        No               No
# 14                 Yes                        No               No
# 15                 Yes                       Yes               No
# 16                 Yes                        No               No
# 17                 Yes                       Yes               No
# 18                 Yes                       Yes               No
# 19                 Yes                        No               No
# 20                 Yes                       Yes               No
# 21                 Yes                        No               No
# 22                 Yes                       Yes               No
# 23                 Yes                       Yes               No
# 24                 Yes                       Yes               No
# 25                 Yes                       Yes               No
# 26                 Yes                        No               No
# 27                 Yes                        No               No
# 28                 Yes                        No               No
# 29                 Yes                        No               No
#
#     learner_dropped_off  overall_score  graduated
# 0                     0      40.875714        NaN
# 1                     0      40.875714        NaN
# 2                     0      40.875714        NaN
# 3                     0      40.875714        NaN
# 4                     0      40.875714        NaN
# 5                     0      40.875714        NaN
# 6                     0      40.875714        NaN
# 7                     0      40.875714        NaN
# 8                     0      40.875714        NaN
# 9                     0      40.875714        NaN
# 10                    0      40.875714        NaN
# 11                    0      40.875714        NaN
# 12                    0      40.875714        NaN
# 13                    0      90.247143        NaN
# 14                    0      90.247143        NaN
# 15                    0      90.247143        NaN
# 16                    0      90.247143        NaN
# 17                    0      90.247143        NaN
# 18                    0      90.247143        NaN
# 19                    0      90.247143        NaN
# 20                    0      90.247143        NaN
# 21                    0      90.247143        NaN
# 22                    0      90.247143        NaN
# 23                    0      90.247143        NaN
# 24                    0      90.247143        NaN
# 25                    0      90.247143        NaN
# 26                    0       0.000000        NaN
# 27                    0       0.000000        NaN
# 28                    0       0.000000        NaN
# 29                    0       0.000000        NaN
